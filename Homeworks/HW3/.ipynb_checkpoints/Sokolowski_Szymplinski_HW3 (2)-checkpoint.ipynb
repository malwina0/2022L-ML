# %% [markdown]
# # Wstęp do uczenia maszynowego - praca domowa nr 3

# %% [markdown]
# #### Budowniczy: Jędrzej Sokołowski, Filip Szympliński
# #### Walidatorzy: Malwina Wojewoda i Jakub Piwko
# #### 8 kwietnia 2022

# %% [markdown]
# Komentarze walidacji oznaczane **W:**

# %% [markdown]
# ### Wczytanie pakietów oraz danych

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import warnings
import copy
warnings.filterwarnings('ignore')

# ustawia domyślną wielkość wykresów
plt.rcParams['figure.figsize'] = (12,12)
# to samo tylko dla tekstu
plt.rcParams['font.size'] = 16
# ustawia wielkość tekstów dla wykresów seaborn zależną od wielkości wykresu
sns.set_context('paper', font_scale=1.4)

# %%
data = pd.read_csv("data.csv", sep=",")

# %%
data
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# 2                                    0.499019
# 3                                    0.451265
# 4                                    0.538432
# ...                                       ...
# 6814                                 0.539468
# 6815                                 0.538269
# 6816                                 0.533744
# 6817                                 0.559911
# 6818                                 0.570105
#
#        ROA(B) before interest and depreciation after tax  \
# 0                                              0.405750
# 1                                              0.516730
# 2                                              0.472295
# 3                                              0.457733
# 4                                              0.522298
# ...                                                 ...
# 6814                                           0.543230
# 6815                                           0.524172
# 6816                                           0.520638
# 6817                                           0.554045
# 6818                                           0.549548
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 0                    0.601457                      0.601457
# 1                    0.610235                      0.610235
# 2                    0.601450                      0.601364
# 3                    0.583541                      0.583541
# 4                    0.598783                      0.598783
# ...                       ...                           ...
# 6814                 0.604455                      0.604462
# 6815                 0.598308                      0.598308
# 6816                 0.610444                      0.610213
# 6817                 0.607850                      0.607850
# 6818                 0.627409                      0.627409
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                   0.998969                    0.796887
# 1                   0.998946                    0.797380
# 2                   0.998857                    0.796403
# 3                   0.998700                    0.796967
# 4                   0.998973                    0.797366
# ...                      ...                         ...
# 6814                0.998992                    0.797409
# 6815                0.998992                    0.797414
# 6816                0.998984                    0.797401
# 6817                0.999074                    0.797500
# 6818                0.998080                    0.801987
#
#        After-tax net Interest Rate  \
# 0                         0.808809
# 1                         0.809301
# 2                         0.808388
# 3                         0.808966
# 4                         0.809304
# ...                            ...
# 6814                      0.809331
# 6815                      0.809327
# 6816                      0.809317
# 6817                      0.809399
# 6818                      0.813800
#
#        Non-industry income and expenditure/revenue  ...  \
# 0                                         0.302646  ...
# 1                                         0.303556  ...
# 2                                         0.302035  ...
# 3                                         0.303350  ...
# 4                                         0.303475  ...
# ...                                            ...  ...
# 6814                                      0.303510  ...
# 6815                                      0.303520  ...
# 6816                                      0.303512  ...
# 6817                                      0.303498  ...
# 6818                                      0.313415  ...
#
#        Net Income to Total Assets   Total assets to GNP price  \
# 0                        0.716845                    0.009219
# 1                        0.795297                    0.008323
# 2                        0.774670                    0.040003
# 3                        0.739555                    0.003252
# 4                        0.795016                    0.003878
# ...                           ...                         ...
# 6814                     0.799927                    0.000466
# 6815                     0.799748                    0.001959
# 6816                     0.797778                    0.002840
# 6817                     0.811808                    0.002837
# 6818                     0.815956                    0.000707
#
#        No-credit Interval   Gross Profit to Sales  \
# 0                0.622879                0.601453
# 1                0.623652                0.610237
# 2                0.623841                0.601449
# 3                0.622929                0.583538
# 4                0.623521                0.598782
# ...                   ...                     ...
# 6814             0.623620                0.604455
# 6815             0.623931                0.598306
# 6816             0.624156                0.610441
# 6817             0.623957                0.607846
# 6818             0.626680                0.627408
#
#        Net Income to Stockholder's Equity   Liability to Equity  \
# 0                                0.827890              0.290202
# 1                                0.839969              0.283846
# 2                                0.836774              0.290189
# 3                                0.834697              0.281721
# 4                                0.839973              0.278514
# ...                                   ...                   ...
# 6814                             0.840359              0.279606
# 6815                             0.840306              0.278132
# 6816                             0.840138              0.275789
# 6817                             0.841084              0.277547
# 6818                             0.841019              0.275114
#
#        Degree of Financial Leverage (DFL)  \
# 0                                0.026601
# 1                                0.264577
# 2                                0.026555
# 3                                0.026697
# 4                                0.024752
# ...                                   ...
# 6814                             0.027064
# 6815                             0.027009
# 6816                             0.026791
# 6817                             0.026822
# 6818                             0.026793
#
#        Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                              0.564050                   1
# 1                                              0.570175                   1
# 2                                              0.563706                   1
# 3                                              0.564663                   1
# 4                                              0.575617                   1
# ...                                                 ...                 ...
# 6814                                           0.566193                   1
# 6815                                           0.566018                   1
# 6816                                           0.565158                   1
# 6817                                           0.565302                   1
# 6818                                           0.565167                   1
#
#        Equity to Liability
# 0                 0.016469
# 1                 0.020794
# 2                 0.016474
# 3                 0.023982
# 4                 0.035490
# ...                    ...
# 6814              0.029890
# 6815              0.038284
# 6816              0.097649
# 6817              0.044009
# 6818              0.233902
#
# [6819 rows x 96 columns]

# %%
from sklearn.model_selection import train_test_split

X = data.drop("Bankrupt?", axis=1)
y = data["Bankrupt?"]
y = y.astype('int')

X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=420, test_size=0.2)

# %%
data_train_val = pd.concat([X_train_val, y_train_val], axis = 1)
data_test = pd.concat([X_test, y_test], axis=1)

# %%
data_train_val
# Out:
#        ROA(C) before interest and depreciation before interest  \
# 5704                                           0.557451
# 3605                                           0.566275
# 4622                                           0.396188
# 2961                                           0.558036
# 4683                                           0.465461
# ...                                                 ...
# 4895                                           0.495149
# 4671                                           0.533369
# 4486                                           0.475260
# 5192                                           0.525764
# 2993                                           0.522059
#
#        ROA(A) before interest and % after tax  \
# 5704                                 0.623583
# 3605                                 0.592619
# 4622                                 0.455789
# 2961                                 0.601723
# 4683                                 0.515100
# ...                                       ...
# 4895                                 0.564054
# 4671                                 0.578609
# 4486                                 0.533635
# 5192                                 0.587440
# 2993                                 0.552824
#
#        ROA(B) before interest and depreciation after tax  \
# 5704                                           0.608116
# 3605                                           0.613256
# 4622                                           0.455860
# 2961                                           0.584078
# 4683                                           0.518175
# ...                                                 ...
# 4895                                           0.546817
# 4671                                           0.595374
# 4486                                           0.525671
# 5192                                           0.576102
# 2993                                           0.565448
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 5704                 0.600182                      0.600182
# 3605                 0.621009                      0.620916
# 4622                 0.596600                      0.596600
# 2961                 0.610559                      0.610581
# 4683                 0.597493                      0.597904
# ...                       ...                           ...
# 4895                 0.605255                      0.604246
# 4671                 0.615201                      0.615201
# 4486                 0.603122                      0.603288
# 5192                 0.603670                      0.603684
# 2993                 0.623978                      0.624238
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 5704                0.998986                    0.797671
# 3605                0.999158                    0.797659
# 4622                0.998466                    0.795514
# 2961                0.999102                    0.797606
# 4683                0.998944                    0.797225
# ...                      ...                         ...
# 4895                0.998979                    0.797437
# 4671                0.999187                    0.797606
# 4486                0.998958                    0.797380
# 5192                0.999018                    0.797447
# 2993                0.999096                    0.797489
#
#        After-tax net Interest Rate  \
# 5704                      0.809552
# 3605                      0.809556
# 4622                      0.807911
# 2961                      0.809448
# 4683                      0.809173
# ...                            ...
# 4895                      0.809360
# 4671                      0.809534
# 4486                      0.809307
# 5192                      0.809362
# 2993                      0.809368
#
#        Non-industry income and expenditure/revenue  \
# 5704                                      0.303980
# 3605                                      0.303601
# 4622                                      0.301299
# 2961                                      0.303624
# 4683                                      0.303290
# ...                                            ...
# 4895                                      0.303587
# 4671                                      0.303445
# 4486                                      0.303531
# 5192                                      0.303523
# 2993                                      0.303433
#
#        Continuous interest rate (after tax)  ...   Total assets to GNP price  \
# 5704                               0.781828  ...                    0.064615
# 3605                               0.781846  ...                    0.040288
# 4622                               0.780086  ...                    0.000658
# 2961                               0.781712  ...                    0.004049
# 4683                               0.781418  ...                    0.075825
# ...                                     ...  ...                         ...
# 4895                               0.781611  ...                    0.002983
# 4671                               0.781813  ...                    0.001395
# 4486                               0.781571  ...                    0.000967
# 5192                               0.781624  ...                    0.003602
# 2993                               0.781694  ...                    0.000620
#
#        No-credit Interval   Gross Profit to Sales  \
# 5704             0.623881                0.600178
# 3605             0.625261                0.621011
# 4622             0.626616                0.596599
# 2961             0.624025                0.610561
# 4683             0.623876                0.597495
# ...                   ...                     ...
# 4895             0.623801                0.605250
# 4671             0.623018                0.615199
# 4486             0.623730                0.603122
# 5192             0.623866                0.603671
# 2993             0.623908                0.623973
#
#        Net Income to Stockholder's Equity   Liability to Equity  \
# 5704                             0.843383              0.276928
# 3605                             0.841936              0.276041
# 4622                             0.837894              0.277069
# 2961                             0.842142              0.275774
# 4683                             0.839328              0.278398
# ...                                   ...                   ...
# 4895                             0.841208              0.279649
# 4671                             0.842245              0.282674
# 4486                             0.840049              0.279763
# 5192                             0.842780              0.282497
# 2993                             0.840782              0.276078
#
#        Degree of Financial Leverage (DFL)  \
# 5704                             0.026792
# 3605                             0.026797
# 4622                             0.026767
# 2961                             0.026791
# 4683                             0.026598
# ...                                   ...
# 4895                             0.027029
# 4671                             0.026954
# 4486                             0.044403
# 5192                             0.026817
# 2993                             0.026794
#
#        Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 5704                                           0.565160                   1
# 3605                                           0.565186                   1
# 4622                                           0.565039                   1
# 2961                                           0.565158                   1
# 4683                                           0.564031                   1
# ...                                                 ...                 ...
# 4895                                           0.566085                   1
# 4671                                           0.565833                   1
# 4486                                           0.569912                   1
# 5192                                           0.565280                   1
# 2993                                           0.565171                   1
#
#        Equity to Liability  Bankrupt?
# 5704              0.053312          0
# 3605              0.081406          0
# 4622              0.050768          0
# 2961              0.098858          0
# 4683              0.036278          0
# ...                    ...        ...
# 4895              0.029717          0
# 4671              0.022342          0
# 4486              0.029282          0
# 5192              0.022617          0
# 2993              0.079525          0
#
# [5455 rows x 96 columns]

# %% [markdown]
# ## Szybkie spojrzenie na dane

# %% [markdown]
# ### Braki danych

# %%
data_train_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5455 entries, 5704 to 2993
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0    ROA(C) before interest and depreciation before interest  5455 non-null   float64
#  1    ROA(A) before interest and % after tax                   5455 non-null   float64
#  2    ROA(B) before interest and depreciation after tax        5455 non-null   float64
#  3    Operating Gross Margin                                   5455 non-null   float64
#  4    Realized Sales Gross Margin                              5455 non-null   float64
#  5    Operating Profit Rate                                    5455 non-null   float64
#  6    Pre-tax net Interest Rate                                5455 non-null   float64
#  7    After-tax net Interest Rate                              5455 non-null   float64
#  8    Non-industry income and expenditure/revenue              5455 non-null   float64
#  9    Continuous interest rate (after tax)                     5455 non-null   float64
#  10   Operating Expense Rate                                   5455 non-null   float64
#  11   Research and development expense rate                    5455 non-null   float64
#  12   Cash flow rate                                           5455 non-null   float64
#  13   Interest-bearing debt interest rate                      5455 non-null   float64
#  14   Tax rate (A)                                             5455 non-null   float64
#  15   Net Value Per Share (B)                                  5455 non-null   float64
#  16   Net Value Per Share (A)                                  5455 non-null   float64
#  17   Net Value Per Share (C)                                  5455 non-null   float64
#  18   Persistent EPS in the Last Four Seasons                  5455 non-null   float64
#  19   Cash Flow Per Share                                      5455 non-null   float64
#  20   Revenue Per Share (Yuan ¥)                               5455 non-null   float64
#  21   Operating Profit Per Share (Yuan ¥)                      5455 non-null   float64
#  22   Per Share Net profit before tax (Yuan ¥)                 5455 non-null   float64
#  23   Realized Sales Gross Profit Growth Rate                  5455 non-null   float64
#  24   Operating Profit Growth Rate                             5455 non-null   float64
#  25   After-tax Net Profit Growth Rate                         5455 non-null   float64
#  26   Regular Net Profit Growth Rate                           5455 non-null   float64
#  27   Continuous Net Profit Growth Rate                        5455 non-null   float64
#  28   Total Asset Growth Rate                                  5455 non-null   float64
#  29   Net Value Growth Rate                                    5455 non-null   float64
#  30   Total Asset Return Growth Rate Ratio                     5455 non-null   float64
#  31   Cash Reinvestment %                                      5455 non-null   float64
#  32   Current Ratio                                            5455 non-null   float64
#  33   Quick Ratio                                              5455 non-null   float64
#  34   Interest Expense Ratio                                   5455 non-null   float64
#  35   Total debt/Total net worth                               5455 non-null   float64
#  36   Debt ratio %                                             5455 non-null   float64
#  37   Net worth/Assets                                         5455 non-null   float64
#  38   Long-term fund suitability ratio (A)                     5455 non-null   float64
#  39   Borrowing dependency                                     5455 non-null   float64
#  40   Contingent liabilities/Net worth                         5455 non-null   float64
#  41   Operating profit/Paid-in capital                         5455 non-null   float64
#  42   Net profit before tax/Paid-in capital                    5455 non-null   float64
#  43   Inventory and accounts receivable/Net value              5455 non-null   float64
#  44   Total Asset Turnover                                     5455 non-null   float64
#  45   Accounts Receivable Turnover                             5455 non-null   float64
#  46   Average Collection Days                                  5455 non-null   float64
#  47   Inventory Turnover Rate (times)                          5455 non-null   float64
#  48   Fixed Assets Turnover Frequency                          5455 non-null   float64
#  49   Net Worth Turnover Rate (times)                          5455 non-null   float64
#  50   Revenue per person                                       5455 non-null   float64
#  51   Operating profit per person                              5455 non-null   float64
#  52   Allocation rate per person                               5455 non-null   float64
#  53   Working Capital to Total Assets                          5455 non-null   float64
#  54   Quick Assets/Total Assets                                5455 non-null   float64
#  55   Current Assets/Total Assets                              5455 non-null   float64
#  56   Cash/Total Assets                                        5455 non-null   float64
#  57   Quick Assets/Current Liability                           5455 non-null   float64
#  58   Cash/Current Liability                                   5455 non-null   float64
#  59   Current Liability to Assets                              5455 non-null   float64
#  60   Operating Funds to Liability                             5455 non-null   float64
#  61   Inventory/Working Capital                                5455 non-null   float64
#  62   Inventory/Current Liability                              5455 non-null   float64
#  63   Current Liabilities/Liability                            5455 non-null   float64
#  64   Working Capital/Equity                                   5455 non-null   float64
#  65   Current Liabilities/Equity                               5455 non-null   float64
#  66   Long-term Liability to Current Assets                    5455 non-null   float64
#  67   Retained Earnings to Total Assets                        5455 non-null   float64
#  68   Total income/Total expense                               5455 non-null   float64
#  69   Total expense/Assets                                     5455 non-null   float64
#  70   Current Asset Turnover Rate                              5455 non-null   float64
#  71   Quick Asset Turnover Rate                                5455 non-null   float64
#  72   Working capitcal Turnover Rate                           5455 non-null   float64
#  73   Cash Turnover Rate                                       5455 non-null   float64
#  74   Cash Flow to Sales                                       5455 non-null   float64
#  75   Fixed Assets to Assets                                   5455 non-null   float64
#  76   Current Liability to Liability                           5455 non-null   float64
#  77   Current Liability to Equity                              5455 non-null   float64
#  78   Equity to Long-term Liability                            5455 non-null   float64
#  79   Cash Flow to Total Assets                                5455 non-null   float64
#  80   Cash Flow to Liability                                   5455 non-null   float64
#  81   CFO to Assets                                            5455 non-null   float64
#  82   Cash Flow to Equity                                      5455 non-null   float64
#  83   Current Liability to Current Assets                      5455 non-null   float64
#  84   Liability-Assets Flag                                    5455 non-null   int64
#  85   Net Income to Total Assets                               5455 non-null   float64
#  86   Total assets to GNP price                                5455 non-null   float64
#  87   No-credit Interval                                       5455 non-null   float64
#  88   Gross Profit to Sales                                    5455 non-null   float64
#  89   Net Income to Stockholder's Equity                       5455 non-null   float64
#  90   Liability to Equity                                      5455 non-null   float64
#  91   Degree of Financial Leverage (DFL)                       5455 non-null   float64
#  92   Interest Coverage Ratio (Interest expense to EBIT)       5455 non-null   float64
#  93   Net Income Flag                                          5455 non-null   int64
#  94   Equity to Liability                                      5455 non-null   float64
#  95  Bankrupt?                                                 5455 non-null   int32
# dtypes: float64(93), int32(1), int64(2)
# memory usage: 4.0 MB

# %%
#W
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1364 entries, 4764 to 2487
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0    ROA(C) before interest and depreciation before interest  1364 non-null   float64
#  1    ROA(A) before interest and % after tax                   1364 non-null   float64
#  2    ROA(B) before interest and depreciation after tax        1364 non-null   float64
#  3    Operating Gross Margin                                   1364 non-null   float64
#  4    Realized Sales Gross Margin                              1364 non-null   float64
#  5    Operating Profit Rate                                    1364 non-null   float64
#  6    Pre-tax net Interest Rate                                1364 non-null   float64
#  7    After-tax net Interest Rate                              1364 non-null   float64
#  8    Non-industry income and expenditure/revenue              1364 non-null   float64
#  9    Continuous interest rate (after tax)                     1364 non-null   float64
#  10   Operating Expense Rate                                   1364 non-null   float64
#  11   Research and development expense rate                    1364 non-null   float64
#  12   Cash flow rate                                           1364 non-null   float64
#  13   Interest-bearing debt interest rate                      1364 non-null   float64
#  14   Tax rate (A)                                             1364 non-null   float64
#  15   Net Value Per Share (B)                                  1364 non-null   float64
#  16   Net Value Per Share (A)                                  1364 non-null   float64
#  17   Net Value Per Share (C)                                  1364 non-null   float64
#  18   Persistent EPS in the Last Four Seasons                  1364 non-null   float64
#  19   Cash Flow Per Share                                      1364 non-null   float64
#  20   Revenue Per Share (Yuan ¥)                               1364 non-null   float64
#  21   Operating Profit Per Share (Yuan ¥)                      1364 non-null   float64
#  22   Per Share Net profit before tax (Yuan ¥)                 1364 non-null   float64
#  23   Realized Sales Gross Profit Growth Rate                  1364 non-null   float64
#  24   Operating Profit Growth Rate                             1364 non-null   float64
#  25   After-tax Net Profit Growth Rate                         1364 non-null   float64
#  26   Regular Net Profit Growth Rate                           1364 non-null   float64
#  27   Continuous Net Profit Growth Rate                        1364 non-null   float64
#  28   Total Asset Growth Rate                                  1364 non-null   float64
#  29   Net Value Growth Rate                                    1364 non-null   float64
#  30   Total Asset Return Growth Rate Ratio                     1364 non-null   float64
#  31   Cash Reinvestment %                                      1364 non-null   float64
#  32   Current Ratio                                            1364 non-null   float64
#  33   Quick Ratio                                              1364 non-null   float64
#  34   Interest Expense Ratio                                   1364 non-null   float64
#  35   Total debt/Total net worth                               1364 non-null   float64
#  36   Debt ratio %                                             1364 non-null   float64
#  37   Net worth/Assets                                         1364 non-null   float64
#  38   Long-term fund suitability ratio (A)                     1364 non-null   float64
#  39   Borrowing dependency                                     1364 non-null   float64
#  40   Contingent liabilities/Net worth                         1364 non-null   float64
#  41   Operating profit/Paid-in capital                         1364 non-null   float64
#  42   Net profit before tax/Paid-in capital                    1364 non-null   float64
#  43   Inventory and accounts receivable/Net value              1364 non-null   float64
#  44   Total Asset Turnover                                     1364 non-null   float64
#  45   Accounts Receivable Turnover                             1364 non-null   float64
#  46   Average Collection Days                                  1364 non-null   float64
#  47   Inventory Turnover Rate (times)                          1364 non-null   float64
#  48   Fixed Assets Turnover Frequency                          1364 non-null   float64
#  49   Net Worth Turnover Rate (times)                          1364 non-null   float64
#  50   Revenue per person                                       1364 non-null   float64
#  51   Operating profit per person                              1364 non-null   float64
#  52   Allocation rate per person                               1364 non-null   float64
#  53   Working Capital to Total Assets                          1364 non-null   float64
#  54   Quick Assets/Total Assets                                1364 non-null   float64
#  55   Current Assets/Total Assets                              1364 non-null   float64
#  56   Cash/Total Assets                                        1364 non-null   float64
#  57   Quick Assets/Current Liability                           1364 non-null   float64
#  58   Cash/Current Liability                                   1364 non-null   float64
#  59   Current Liability to Assets                              1364 non-null   float64
#  60   Operating Funds to Liability                             1364 non-null   float64
#  61   Inventory/Working Capital                                1364 non-null   float64
#  62   Inventory/Current Liability                              1364 non-null   float64
#  63   Current Liabilities/Liability                            1364 non-null   float64
#  64   Working Capital/Equity                                   1364 non-null   float64
#  65   Current Liabilities/Equity                               1364 non-null   float64
#  66   Long-term Liability to Current Assets                    1364 non-null   float64
#  67   Retained Earnings to Total Assets                        1364 non-null   float64
#  68   Total income/Total expense                               1364 non-null   float64
#  69   Total expense/Assets                                     1364 non-null   float64
#  70   Current Asset Turnover Rate                              1364 non-null   float64
#  71   Quick Asset Turnover Rate                                1364 non-null   float64
#  72   Working capitcal Turnover Rate                           1364 non-null   float64
#  73   Cash Turnover Rate                                       1364 non-null   float64
#  74   Cash Flow to Sales                                       1364 non-null   float64
#  75   Fixed Assets to Assets                                   1364 non-null   float64
#  76   Current Liability to Liability                           1364 non-null   float64
#  77   Current Liability to Equity                              1364 non-null   float64
#  78   Equity to Long-term Liability                            1364 non-null   float64
#  79   Cash Flow to Total Assets                                1364 non-null   float64
#  80   Cash Flow to Liability                                   1364 non-null   float64
#  81   CFO to Assets                                            1364 non-null   float64
#  82   Cash Flow to Equity                                      1364 non-null   float64
#  83   Current Liability to Current Assets                      1364 non-null   float64
#  84   Liability-Assets Flag                                    1364 non-null   int64
#  85   Net Income to Total Assets                               1364 non-null   float64
#  86   Total assets to GNP price                                1364 non-null   float64
#  87   No-credit Interval                                       1364 non-null   float64
#  88   Gross Profit to Sales                                    1364 non-null   float64
#  89   Net Income to Stockholder's Equity                       1364 non-null   float64
#  90   Liability to Equity                                      1364 non-null   float64
#  91   Degree of Financial Leverage (DFL)                       1364 non-null   float64
#  92   Interest Coverage Ratio (Interest expense to EBIT)       1364 non-null   float64
#  93   Net Income Flag                                          1364 non-null   int64
#  94   Equity to Liability                                      1364 non-null   float64
#  95  Bankrupt?                                                 1364 non-null   int32
# dtypes: float64(93), int32(1), int64(2)
# memory usage: 1.0 MB

# %% [markdown]
# Wszystkie dane są liczbami

# %%
sum(list(data_train_val.isna().sum()))
# Out:
# 0

# %%
sum(data_train_val[data_train_val == -1].count())
# Out:
# 0

# %%
#W
sum(list(data_test.isna().sum()))
# Out:
# 0

# %%
#W
sum(data_test[data_test == -1].count())
# Out:
# 0

# %% [markdown]
# Brak braków danych

# %% [markdown]
# **W:** Potwierdzamy.

# %% [markdown]
# ### Rozkłady zmiannych

# %%
data_train_val.hist(bins = 20, figsize=(20, 20), color="gray")
plt.show()

# %%
sns.countplot(x="Bankrupt?", data=data_train_val, color='gray')
# Out:
# <AxesSubplot:xlabel='Bankrupt?', ylabel='count'>

# %% [markdown]
# Widać tutaj, że mamy mocno niezbalansowane klasy

# %%
#W
sns.countplot(x="Bankrupt?", data=data_test, color='gray')
# Out:
# <AxesSubplot:xlabel='Bankrupt?', ylabel='count'>

# %% [markdown]
# **W:** Proporcje klas mają identyczne proporcje w zbiorze waidaycjnym.

# %% [markdown]
# ---

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Outliery

# %%
col_names = data_train_val.columns
indexes_set = set()
num_of_outliers = []

for col in col_names:
    tmp_data1 = data_train_val[col]
    upper_lim1 = tmp_data1.quantile(.975)
    lower_lim1 = tmp_data1.quantile(.025)
    data_train_val[col] = np.where(data_train_val[col] < upper_lim1, data_train_val[col], upper_lim1)
    data_train_val[col] = np.where(data_train_val[col] > lower_lim1, data_train_val[col], lower_lim1)

# %% [markdown]
# Dla każdej kolumny outliery zostały zastąpione wartościami granicznymi.
#
# Ze względu na charakter danych trzeba być bardzo ostrożnym z usuwaniem obserwacji, ponieważ naturalne jest, że gdy dana firma bankrutuje, to różne wskaźniki odbiegają mniej bądź bardziej od normy. Aby określić czy coś nie ma pokrycia z rzeczywistością należy posiadać specjalistyczną wiedzę.
#
# Uwaga odnośnie wybierania outlierów. Otwarty przedział wynika z tego, że jeśli w danej kolumnie są przykładowo jedynie wartości równe 1, to przy zamkniętych przedziałach, zosatałyby usunięte wszystkie wartości, dlatego została podjęta taka decyzja.

# %%
#W
data_test.describe()
# Out:
#         ROA(C) before interest and depreciation before interest  \
# count                                        1364.000000
# mean                                            0.505489
# std                                             0.061609
# min                                             0.216984
# 25%                                             0.477502
# 50%                                             0.501828
# 75%                                             0.535941
# max                                             1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              1364.000000
# mean                                  0.558745
# std                                   0.067980
# min                                   0.090711
# 25%                                   0.535775
# 50%                                   0.558929
# 75%                                   0.588244
# max                                   0.954536
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        1364.000000
# mean                                            0.553521
# std                                             0.062403
# min                                             0.171637
# 25%                                             0.528187
# 50%                                             0.551314
# 75%                                             0.583971
# max                                             0.957760
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              1364.000000                   1364.000000
# mean                  0.607703                      0.607706
# std                   0.024151                      0.024163
# min                   0.000000                      0.000000
# 25%                   0.600906                      0.600881
# 50%                   0.606606                      0.606621
# 75%                   0.614260                      0.614233
# max                   0.665151                      0.665151
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             1364.000000                 1364.000000
# mean                 0.998930                    0.797268
# std                  0.001192                    0.005019
# min                  0.962961                    0.616328
# 25%                  0.998971                    0.797389
# 50%                  0.999020                    0.797467
# 75%                  0.999099                    0.797577
# max                  0.999644                    0.809513
#
#         After-tax net Interest Rate  \
# count                   1364.000000
# mean                       0.809180
# std                        0.004808
# min                        0.636191
# 25%                        0.809314
# 50%                        0.809377
# 75%                        0.809468
# max                        0.821053
#
#         Non-industry income and expenditure/revenue  \
# count                                   1364.000000
# mean                                       0.303394
# std                                        0.006636
# min                                        0.062507
# 25%                                        0.303468
# 50%                                        0.303528
# 75%                                        0.303588
# max                                        0.329207
#
#         Continuous interest rate (after tax)  ...   Total assets to GNP price  \
# count                            1364.000000  ...                1.364000e+03
# mean                                0.781522  ...                2.281085e+07
# std                                 0.002140  ...                4.379566e+08
# min                                 0.712333  ...                1.085313e-04
# 25%                                 0.781569  ...                9.064894e-04
# 50%                                 0.781636  ...                2.000487e-03
# 75%                                 0.781734  ...                4.912516e-03
# max                                 0.795631  ...                9.390000e+09
#
#         No-credit Interval   Gross Profit to Sales  \
# count          1364.000000             1364.000000
# mean              0.624352                0.607701
# std               0.016039                0.024151
# min               0.408682                0.000000
# 25%               0.623644                0.600904
# 50%               0.623879                0.606606
# 75%               0.624149                0.614258
# max               1.000000                0.665149
#
#         Net Income to Stockholder's Equity   Liability to Equity  \
# count                          1364.000000           1364.000000
# mean                              0.840348              0.280420
# std                               0.012856              0.020809
# min                               0.442176              0.199162
# 25%                               0.840140              0.276820
# 50%                               0.841103              0.278586
# 75%                               0.842337              0.281100
# max                               0.902744              1.000000
#
#         Degree of Financial Leverage (DFL)  \
# count                          1364.000000
# mean                              0.027350
# std                               0.009770
# min                               0.020760
# 25%                               0.026791
# 50%                               0.026807
# 75%                               0.026913
# max                               0.367190
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        1364.000000              1364.0
# mean                                            0.565732                 1.0
# std                                             0.007767                 0.0
# min                                             0.500799                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565241                 1.0
# 75%                                             0.565723                 1.0
# max                                             0.735958                 1.0
#
#         Equity to Liability    Bankrupt?
# count           1364.000000  1364.000000
# mean               0.049202     0.030059
# std                0.050826     0.170811
# min                0.008950     0.000000
# 25%                0.025311     0.000000
# 50%                0.034999     0.000000
# 75%                0.055371     0.000000
# max                0.881018     1.000000
#
# [8 rows x 96 columns]

# %%
#W
col_names = data_test.columns
indexes_set = set()
num_of_outliers = []

for col in col_names:
    tmp_data1 = data_test[col]
    upper_lim1 = tmp_data1.quantile(.975)
    lower_lim1 = tmp_data1.quantile(.025)
    data_test[col] = np.where(data_test[col] < upper_lim1, data_test[col], upper_lim1)
    data_test[col] = np.where(data_test[col] > lower_lim1, data_test[col], lower_lim1)

# %%
#W
data_test.describe()
# Out:
#         ROA(C) before interest and depreciation before interest  \
# count                                        1364.000000
# mean                                            0.505659
# std                                             0.053705
# min                                             0.380149
# 25%                                             0.477502
# 50%                                             0.501828
# 75%                                             0.535941
# max                                             0.639509
#
#         ROA(A) before interest and % after tax  \
# count                              1364.000000
# mean                                  0.559756
# std                                   0.057116
# min                                   0.409934
# 25%                                   0.535775
# 50%                                   0.558929
# 75%                                   0.588244
# max                                   0.702371
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        1364.000000
# mean                                            0.554290
# std                                             0.054112
# min                                             0.419360
# 25%                                             0.528187
# 50%                                             0.551314
# 75%                                             0.583971
# max                                             0.689314
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              1364.000000                   1364.000000
# mean                  0.608550                      0.608554
# std                   0.010793                      0.010825
# min                   0.590950                      0.590950
# 25%                   0.600906                      0.600881
# 50%                   0.606606                      0.606621
# 75%                   0.614260                      0.614233
# max                   0.639327                      0.639469
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             1364.000000                 1364.000000
# mean                 0.999012                    0.797441
# std                  0.000169                    0.000269
# min                  0.998339                    0.796420
# 25%                  0.998971                    0.797389
# 50%                  0.999020                    0.797467
# 75%                  0.999099                    0.797577
# max                  0.999304                    0.797924
#
#         After-tax net Interest Rate  \
# count                   1364.000000
# mean                       0.809348
# std                        0.000255
# min                        0.808292
# 25%                        0.809314
# 50%                        0.809377
# 75%                        0.809468
# max                        0.809771
#
#         Non-industry income and expenditure/revenue  \
# count                                   1364.000000
# mean                                       0.303525
# std                                        0.000229
# min                                        0.302774
# 25%                                        0.303468
# 50%                                        0.303528
# 75%                                        0.303588
# max                                        0.304229
#
#         Continuous interest rate (after tax)  ...   Total assets to GNP price  \
# count                            1364.000000  ...                 1364.000000
# mean                                0.781609  ...                    0.005713
# std                                 0.000252  ...                    0.011130
# min                                 0.780648  ...                    0.000257
# 25%                                 0.781569  ...                    0.000906
# 50%                                 0.781636  ...                    0.002000
# 75%                                 0.781734  ...                    0.004913
# max                                 0.782035  ...                    0.060290
#
#         No-credit Interval   Gross Profit to Sales  \
# count          1364.000000             1364.000000
# mean              0.623843                0.608548
# std               0.001014                0.010793
# min               0.620413                0.590948
# 25%               0.623644                0.600904
# 50%               0.623879                0.606606
# 75%               0.624149                0.614258
# max               0.626773                0.639327
#
#         Net Income to Stockholder's Equity   Liability to Equity  \
# count                          1364.000000           1364.000000
# mean                              0.840896              0.279565
# std                               0.002502              0.003753
# min                               0.833031              0.275347
# 25%                               0.840140              0.276820
# 50%                               0.841103              0.278586
# 75%                               0.842337              0.281100
# max                               0.845687              0.291773
#
#         Degree of Financial Leverage (DFL)  \
# count                          1364.000000
# mean                              0.026937
# std                               0.000479
# min                               0.026178
# 25%                               0.026791
# 50%                               0.026807
# 75%                               0.026913
# max                               0.029037
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        1364.000000              1364.0
# mean                                            0.565505                 1.0
# std                                             0.001247                 0.0
# min                                             0.562055                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565241                 1.0
# 75%                                             0.565723                 1.0
# max                                             0.569430                 1.0
#
#         Equity to Liability    Bankrupt?
# count           1364.000000  1364.000000
# mean               0.046475     0.030059
# std                0.031916     0.170811
# min                0.015829     0.000000
# 25%                0.025311     0.000000
# 50%                0.034999     0.000000
# 75%                0.055371     0.000000
# max                0.154737     1.000000
#
# [8 rows x 96 columns]

# %% [markdown]
# **W:** Zastąpienie outlierami wartościami granicznymi jest jak najbardziej w porządku. Jak widać w sumarycznych statystykach dla danych przed i po, niektóre zmienne miały wyraźnie odstające wartości.

# %% [markdown]
# ### Skalowanie

# %%
cols_to_scale = []
for col in data_train_val.columns:
    if data[col].max() > 1:
        cols_to_scale.append(col)
print(cols_to_scale)
len(cols_to_scale)
# Out:
# [' Operating Expense Rate', ' Research and development expense rate', ' Interest-bearing debt interest rate', ' Revenue Per Share (Yuan ¥)', ' Total Asset Growth Rate', ' Net Value Growth Rate', ' Current Ratio', ' Quick Ratio', ' Total debt/Total net worth', ' Accounts Receivable Turnover', ' Average Collection Days', ' Inventory Turnover Rate (times)', ' Fixed Assets Turnover Frequency', ' Revenue per person', ' Allocation rate per person', ' Quick Assets/Current Liability', ' Cash/Current Liability', ' Inventory/Current Liability', ' Long-term Liability to Current Assets', ' Current Asset Turnover Rate', ' Quick Asset Turnover Rate', ' Cash Turnover Rate', ' Fixed Assets to Assets', ' Total assets to GNP price']
# 24

# %% [markdown]
# Wychodzi na to, że są łącznie 24 kolumny, które należałoby przeskalować. Sprawdzenie czy nie ma wartości ujemnych zostało dokonane wcześniej.
#
# Wszystkie kolumny, których wartości nie zawierają się jedynie w przedziale [0, 1] zostaną przeskalowane.

# %%
for col in cols_to_scale:
    min_max_scaler1 = MinMaxScaler()
    scaled_col1 = min_max_scaler1.fit_transform(data_train_val[col].values.reshape(-1, 1))
    data_train_val[col] = scaled_col1

# %%
#W
cols_to_scale = []
for col in data_test.columns:
    if data[col].max() > 1:
        cols_to_scale.append(col)
print(cols_to_scale)
len(cols_to_scale)
# Out:
# [' Operating Expense Rate', ' Research and development expense rate', ' Interest-bearing debt interest rate', ' Revenue Per Share (Yuan ¥)', ' Total Asset Growth Rate', ' Net Value Growth Rate', ' Current Ratio', ' Quick Ratio', ' Total debt/Total net worth', ' Accounts Receivable Turnover', ' Average Collection Days', ' Inventory Turnover Rate (times)', ' Fixed Assets Turnover Frequency', ' Revenue per person', ' Allocation rate per person', ' Quick Assets/Current Liability', ' Cash/Current Liability', ' Inventory/Current Liability', ' Long-term Liability to Current Assets', ' Current Asset Turnover Rate', ' Quick Asset Turnover Rate', ' Cash Turnover Rate', ' Fixed Assets to Assets', ' Total assets to GNP price']
# 24

# %%
#W
for col in cols_to_scale:
    min_max_scaler1 = MinMaxScaler()
    scaled_col1 = min_max_scaler1.fit_transform(data_test[col].values.reshape(-1, 1))
    data_test[col] = scaled_col1

# %% [markdown]
# **W:** W zbiorze walidaycjnym te same zmienne wymagały przeskalowania.

# %% [markdown]
# ### Redukcja zmiennych silnie skorelowanych

# %%
plt.figure(figsize=(30,25))
corr = data_train_val.corr(method = 'spearman')
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values, fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
correlated_features = set()

for i in range(len(corr .columns)):
    for j in range(i):
        if abs(corr.iloc[i, j]) >= 0.95:
            colname = corr.columns[i]
            correlated_features.add(colname)

# %%
print(correlated_features)
print(len(correlated_features))
len(correlated_features)/data_train_val.shape[1]
# Out:
# {' Net Value Per Share (A)', ' Realized Sales Gross Margin', ' CFO to Assets', ' Current Liability to Current Assets', " Net Income to Stockholder's Equity", ' Net Income to Total Assets', ' Operating Funds to Liability', ' Operating profit/Paid-in capital', ' Fixed Assets to Assets', ' Current Liabilities/Equity', ' Current Liability to Liability', ' After-tax net Interest Rate', ' Net worth/Assets', ' Current Liability to Equity', ' Debt ratio %', ' Net profit before tax/Paid-in capital', ' Liability to Equity', ' Per Share Net profit before tax (Yuan ¥)', ' Equity to Liability', ' Regular Net Profit Growth Rate', ' Quick Assets/Current Liability', ' Cash Flow to Total Assets', ' Gross Profit to Sales', ' Cash Flow to Equity', ' ROA(B) before interest and depreciation after tax', ' Average Collection Days', ' Net Value Per Share (C)', ' Continuous interest rate (after tax)', ' Cash Flow to Liability'}
# 29
# 0.3020833333333333

# %%
data_train_val.drop(labels=correlated_features, axis=1, inplace=True)

# %% [markdown]
# Pozbyliśmy się 29 kolumn, dla których wspołczynnik korelacji z którąś inną kolumną wynosił więcej niż 0.95 .

# %%
#W
plt.figure(figsize=(30,25))
corr = data_test.corr(method = 'spearman')
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values, fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
#W
correlated_features = set()

for i in range(len(corr .columns)):
    for j in range(i):
        if abs(corr.iloc[i, j]) >= 0.95:
            colname = corr.columns[i]
            correlated_features.add(colname)

# %%
#W
import copy 
data_copy = copy.deepcopy(data_test)

# %%
#W
print(correlated_features)
print(len(correlated_features))
len(correlated_features)/data_test.shape[1]
# Out:
# {' Net Value Per Share (A)', ' Realized Sales Gross Margin', ' CFO to Assets', ' Current Liability to Current Assets', " Net Income to Stockholder's Equity", ' Net Income to Total Assets', ' Operating Funds to Liability', ' Operating profit/Paid-in capital', ' Persistent EPS in the Last Four Seasons', ' Fixed Assets to Assets', ' Current Liabilities/Equity', ' Current Liability to Liability', ' After-tax net Interest Rate', ' Net worth/Assets', ' Current Liability to Equity', ' Debt ratio %', ' Net profit before tax/Paid-in capital', ' Liability to Equity', ' Per Share Net profit before tax (Yuan ¥)', ' Equity to Liability', ' Regular Net Profit Growth Rate', ' Quick Assets/Current Liability', ' Cash Flow to Total Assets', ' Gross Profit to Sales', ' Cash Flow to Equity', ' ROA(B) before interest and depreciation after tax', ' Net Value Per Share (C)', ' Continuous interest rate (after tax)', ' Cash Flow to Liability'}
# 29
# 0.3020833333333333

# %%
#W
data_test.drop(labels=correlated_features, axis=1, inplace=True)

# %% [markdown]
# **W:** Na zbiorze walidacyjnym również 29 kolumn spełniło warunek wysokiej korelacji, także pozbyliśmy się ich z ramki.

# %%
#W
from sklearn.ensemble import RandomForestClassifier

corr = data_copy.corr(method = 'spearman')
y = data_copy['Bankrupt?']
X = data_copy.drop('Bankrupt?', axis = 1)

Forest = RandomForestClassifier()
Forest.fit(X, y)
fi = Forest.feature_importances_
correlated_features = set()


for i in range(len(corr .columns)):
    for j in range(i):
        if abs(corr.iloc[i, j]) >= 0.95:
            if fi[i] >= fi[j]:
                correlated_features.add(corr.columns[i])
            else:
                correlated_features.add(corr.columns[j])

# %%
#W
print(correlated_features)
print(len(correlated_features))
len(correlated_features)/X.shape[1]
# Out:
# {' Net Value Per Share (A)', ' Realized Sales Gross Margin', ' After-tax Net Profit Growth Rate', ' Current Liability to Current Assets', " Net Income to Stockholder's Equity", ' Net Income to Total Assets', ' Net Value Per Share (B)', ' Total debt/Total net worth', ' Persistent EPS in the Last Four Seasons', ' Fixed Assets to Assets', ' Current Liabilities/Equity', ' Current Liability to Liability', ' After-tax net Interest Rate', ' Net worth/Assets', ' Operating Profit Per Share (Yuan ¥)', ' Current Liability to Equity', ' Debt ratio %', ' Net profit before tax/Paid-in capital', ' Per Share Net profit before tax (Yuan ¥)', ' Equity to Liability', ' Cash Flow to Total Assets', ' Gross Profit to Sales', ' Quick Ratio', ' Cash Flow to Equity', ' ROA(B) before interest and depreciation after tax', ' Cash flow rate', ' Continuous interest rate (after tax)', ' Cash Flow Per Share', ' Cash Flow to Liability'}
# 29
# 0.30526315789473685

# %% [markdown]
# **W:** Aby usprawnić proces usuwania kolumn, spośród par zmiennych wysoko skorelowanych można usuwać te, które mają gorszą predykcyjność. W przykładzie powyżej wykorzystaliśmy Feature Importance dla modelu Random Forest. Dostaliśmy w wyniku nieco inne kolumny do usunięcia. Można się też zastanowić nad wyborem mniejszego progu korelacji, choć delikatne zmniejszenie progu dla tego zbioru szybko zwiększa liczbę kolumn do usunięcia, więc wydaje się, że korelacja na poziomie 0.95 i 29 zmiennych to optymalne wartości, aby nie pozbyć się za dużo informacji.

# %% [markdown]
# ### Zmiana kierunku zmiennych

# %%
corr = data_train_val.corr(method = 'spearman')
(corr["Bankrupt?"] < 0).sum()
# Out:
# 45

# %%
columns = data_train_val.drop("Bankrupt?", axis=1).columns

for col in columns:
    if corr["Bankrupt?"][col] < 0:
      data_train_val[col] *= -1

# %%
corr = data_train_val.corr(method = 'spearman')
(corr["Bankrupt?"] < 0).sum()
# Out:
# 0

# %% [markdown]
# Teraz wszystke zmienne są dodatnio skorelowane ze zmienną celu.

# %%
#W
corr = data_test.corr(method = 'spearman')
(corr["Bankrupt?"] < 0).sum()
# Out:
# 44

# %%
#W
columns = data_test.drop("Bankrupt?", axis=1).columns

for col in columns:
    if corr["Bankrupt?"][col] < 0:
      data_test[col] *= -1

# %%
#W
corr = data_test.corr(method = 'spearman')
(corr["Bankrupt?"] < 0).sum()
# Out:
# 0

# %% [markdown]
# **W:** W zbiorze walidacyjnym jedna zmienna mniej miała ujemną korelacją Spearmana. Zapewne była to zmienna, której moduł korelacji jest bardzo mały.

# %% [markdown]
# ## Modelowanie

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsOneClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, roc_curve, confusion_matrix, precision_score, recall_score
from sklearn.model_selection import cross_val_predict
from tqdm.notebook import tqdm

# %%
def show_model_metrics(model, X, y):
    y_pred = model.predict(X)
    print(f"F1 score: {f1_score(y, y_pred, average=None)}")
    print(f"F1 score micro: {f1_score(y, y_pred, average='micro')}")
    print(f"F1 score weighted: {f1_score(y, y_pred, average='weighted')}")
    print(f"Precision score: {precision_score(y, y_pred, average=None)}")
    print(f"Recall score: {recall_score(y, y_pred, average=None)}")

# %%
from sklearn.model_selection import train_test_split

X = data_train_val.drop("Bankrupt?", axis=1)
y = data_train_val["Bankrupt?"]
y = y.astype('int')

X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=420, test_size=0.125) #Tutaj było podane X_train_val i y_train_val, ale to chyba pomyłka

# %%
from sklearn.model_selection import train_test_split

X = data_test.drop("Bankrupt?", axis=1)
y = data_test["Bankrupt?"]
y = y.astype('int')

X_trainv, X_valv, y_trainv, y_valv = train_test_split(X_test, y_test, random_state=420, test_size=0.2)

# %% [markdown]
# ## Klasyfikator `XGBClassifier`

# %%
xgb_clf = xgb.XGBClassifier(random_state=1,
                    booster='gbtree', 
                    use_label_encoder=False)
xgb_clf.fit(X_train, y_train)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(xgb_clf, X_train, y_train)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(xgb_clf, X_test, y_test)
# Out:
# [08:43:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------------------------------------------
# Train set scores
# F1 score: [1. 1.]
# F1 score micro: 1.0
# F1 score weighted: 1.0
# Precision score: [1. 1.]
# Recall score: [1. 1.]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.98650675 0.4       ]
# F1 score micro: 0.9736070381231671
# F1 score weighted: 0.96887714500521
# Precision score: [0.97843866 0.63157895]
# Recall score: [0.99470899 0.29268293]

# %%
xgb_clf = xgb.XGBClassifier(random_state=1,
                    booster='gbtree', 
                    use_label_encoder=False,
                    max_depth=2,
                    learning_rate=0.3
                    )
xgb_clf.fit(X_train, y_train)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(xgb_clf, X_train, y_train)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(xgb_clf, X_val, y_val)
# Out:
# [19:44:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------------------------------------------
# Train set scores
# F1 score: [0.99654577 0.88652482]
# F1 score micro: 0.993295621202598
# F1 score weighted: 0.9929498608447368
# Precision score: [0.99332903 0.99206349]
# Recall score: [0.99978341 0.80128205]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.98266767 0.37837838]
# F1 score micro: 0.966275659824047
# F1 score weighted: 0.9622884137554631
# Precision score: [0.9760479 0.5      ]
# Recall score: [0.98937785 0.30434783]

# %%
cols = ["n_estimators","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(1,100,5)
for trees_nr in tqdm(estimators):
    xgb_clf = xgb.XGBClassifier(n_estimators=trees_nr, max_depth=3, eval_metric='logloss').fit(X_train, y_train)
    train_score = roc_auc_score(y_train, xgb_clf.predict(X_train))
    val_score = roc_auc_score(y_val, xgb_clf.predict(X_val))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_estimators", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))

# %%
cols = ["n_estimators","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(1,20,1)
for trees_nr in tqdm(estimators):
    xgb_clf = xgb.XGBClassifier(n_estimators=trees_nr, max_depth=3, eval_metric='logloss').fit(X_train, y_train)
    train_score = roc_auc_score(y_train, xgb_clf.predict(X_train))
    val_score = roc_auc_score(y_val, xgb_clf.predict(X_val))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_estimators", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=19.0), HTML(value='')))

# %%
cols = ["n_depth","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

n_depth = np.arange(1,10,1)
for depth in tqdm(n_depth):
    xgb_clf = xgb.XGBClassifier(max_depth=depth, eval_metric='logloss').fit(X_train, y_train)
    train_score = roc_auc_score(y_train,xgb_clf.predict(X_train))
    val_score = roc_auc_score(y_val,xgb_clf.predict(X_val))
    history = history.append(dict(zip(cols, [depth, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [depth, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_depth", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %%
cols = ["n_learning_rate","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

n_rate = np.arange(0.01,0.2,0.02)
for rate in tqdm(n_rate):
    xgb_clf = xgb.XGBClassifier(learning_rate=rate, eval_metric='logloss').fit(X_train, y_train)
    train_score = roc_auc_score(y_train,xgb_clf.predict(X_train))
    val_score = roc_auc_score(y_val,xgb_clf.predict(X_val))
    history = history.append(dict(zip(cols, [rate, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [rate, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_learning_rate", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %% [markdown]
# Z powyższych wyników widać, że metryką nad której wynikiem należało popracować (jeśli się by dobierało parametry) jest `Recall` dla obserwacji zbankrutowanych przedsiębiorstw.
#
# ***
# ***

# %%
#W
xgb_clf = xgb.XGBClassifier(random_state=1,
                    booster='gbtree', 
                    use_label_encoder=False)
xgb_clf.fit(X_trainv, y_trainv)

print("--------------------------------------------------")
print("Validation train set scores")
show_model_metrics(xgb_clf, X_trainv, y_trainv)

print("--------------------------------------------------")
print("Validation test set scores")
show_model_metrics(xgb_clf, X_valv, y_valv)
# Out:
# [19:45:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------------------------------------------
# Validation train set scores
# F1 score: [1. 1.]
# F1 score micro: 1.0
# F1 score weighted: 1.0
# Precision score: [1. 1.]
# Recall score: [1. 1.]
# --------------------------------------------------
# Validation test set scores
# F1 score: [0.98127341 0.16666667]
# F1 score micro: 0.9633699633699634
# F1 score weighted: 0.9514343334568052
# Precision score: [0.96678967 0.5       ]
# Recall score: [0.99619772 0.1       ]

# %%
#W
xgb_clf = xgb.XGBClassifier(random_state=1,
                    booster='gbtree', 
                    use_label_encoder=False,
                    max_depth=2,
                    learning_rate=0.3
                    )
xgb_clf.fit(X_trainv, y_trainv)

print("--------------------------------------------------")
print("Validation Train set scores")
show_model_metrics(xgb_clf, X_trainv, y_trainv)

print("--------------------------------------------------")
print("Validation test set scores")
show_model_metrics(xgb_clf, X_valv, y_valv)
# Out:
# [19:45:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# --------------------------------------------------
# Validation Train set scores
# F1 score: [1. 1.]
# F1 score micro: 1.0
# F1 score weighted: 1.0
# Precision score: [1. 1.]
# Recall score: [1. 1.]
# --------------------------------------------------
# Validation test set scores
# F1 score: [0.98127341 0.16666667]
# F1 score micro: 0.9633699633699634
# F1 score weighted: 0.9514343334568052
# Precision score: [0.96678967 0.5       ]
# Recall score: [0.99619772 0.1       ]

# %%
#W
cols = ["n_estimators","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(1,100,5)
for trees_nr in tqdm(estimators):
    xgb_clf = xgb.XGBClassifier(n_estimators=trees_nr, max_depth=3, eval_metric='logloss').fit(X_trainv, y_trainv)
    train_score = roc_auc_score(y_trainv, xgb_clf.predict(X_trainv))
    val_score = roc_auc_score(y_valv, xgb_clf.predict(X_valv))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_estimators", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))

# %%
#W
cols = ["n_estimators","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(1,20,1)
for trees_nr in tqdm(estimators):
    xgb_clf = xgb.XGBClassifier(n_estimators=trees_nr, max_depth=3, eval_metric='logloss').fit(X_trainv, y_trainv)
    train_score = roc_auc_score(y_trainv, xgb_clf.predict(X_trainv))
    val_score = roc_auc_score(y_valv, xgb_clf.predict(X_valv))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_estimators", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=19.0), HTML(value='')))

# %%
#W
cols = ["n_depth","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

n_depth = np.arange(1,10,1)
for depth in tqdm(n_depth):
    xgb_clf = xgb.XGBClassifier(max_depth=depth, eval_metric='logloss').fit(X_trainv, y_trainv)
    train_score = roc_auc_score(y_train,xgb_clf.predict(X_train))
    val_score = roc_auc_score(y_valv,xgb_clf.predict(X_valv))
    history = history.append(dict(zip(cols, [depth, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [depth, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_depth", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %%
#W
cols = ["n_learning_rate","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

n_rate = np.arange(0.01,0.2,0.02)
for rate in tqdm(n_rate):
    xgb_clf = xgb.XGBClassifier(learning_rate=rate, eval_metric='logloss').fit(X_trainv, y_trainv)
    train_score = roc_auc_score(y_trainv,xgb_clf.predict(X_trainv))
    val_score = roc_auc_score(y_valv,xgb_clf.predict(X_valv))
    history = history.append(dict(zip(cols, [rate, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [rate, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_learning_rate", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %% [markdown]
# ## Klasyfikator `RandomForestClassifier`

# %%
rndForest = RandomForestClassifier()
rndForest.fit(X_train, y_train)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(rndForest, X_train, y_train)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(rndForest, X_val, y_val)
# Out:
# --------------------------------------------------
# Train set scores
# F1 score: [1. 1.]
# F1 score micro: 1.0
# F1 score weighted: 1.0
# Precision score: [1. 1.]
# Recall score: [1. 1.]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.98279731 0.14814815]
# F1 score micro: 0.966275659824047
# F1 score weighted: 0.9546493152302982
# Precision score: [0.96902655 0.5       ]
# Recall score: [0.9969651  0.08695652]

# %% [markdown]
# Widać tutaj mocne przetrenowanie kosztem predykcyjności dla zbankrutowanych przedsiębiorstw.

# %% [markdown]
# Podobnie jak w przypadku XGBoost krytyczną metryką jest `Recall` dla przedsiębiorstw, które zbankrutowały. Naturalnie F1 score dla tej klasy też nie jest najlepszy, ale to wynika z tego, że ta metryka jest zalezna od recall.

# %%
cols = ["n_estimators","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(3,300,5)
for trees_nr in tqdm(estimators):
    rf = RandomForestClassifier(n_estimators=trees_nr, max_depth=5, n_jobs=-1).fit(X_train, y_train)
    train_score = roc_auc_score(y_train, rf.predict(X_train))
    val_score = roc_auc_score(y_val, rf.predict(X_val))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_estimators", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=60.0), HTML(value='')))

# %%
sns.lineplot(data=history, x = "n_estimators", y = "AUC", hue = "dataset")
plt.show()

# %% [markdown]
# ---

# %%
cols = ["n_estimators","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(3,96,3)
for trees_nr in tqdm(estimators):
    rf = RandomForestClassifier(n_estimators=trees_nr, max_depth=5, n_jobs=-1).fit(X_train, y_train)
    train_score = roc_auc_score(y_train, rf.predict(X_train))
    val_score = roc_auc_score(y_val, rf.predict(X_val))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=31.0), HTML(value='')))

# %%
sns.lineplot(data=history, x = "n_estimators", y = "AUC", hue = "dataset")
plt.show()

# %% [markdown]
# ---

# %%
cols = ["n_depth","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

n_depth = np.arange(1,10,1)
for depth in tqdm(n_depth):
    rf = RandomForestClassifier(max_depth=depth, n_jobs=-1, n_estimators=100).fit(X_train, y_train)
    train_score = roc_auc_score(y_train,rf.predict(X_train))
    val_score = roc_auc_score(y_val,rf.predict(X_val))
    history = history.append(dict(zip(cols, [depth, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [depth, val_score, "val"])), ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %%
sns.lineplot(data=history, x = "n_depth", y = "AUC", hue = "dataset")
plt.show()

# %%
cols = ["n_depth","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

n_depth = np.arange(1,10,1)
for depth in tqdm(n_depth):
    rf = RandomForestClassifier(max_depth=depth, n_jobs=-1, n_estimators=100).fit(X_train, y_train)
    train_score = rf.score(X_train,y_train)
    val_score = rf.score(X_val,y_val)
    history = history.append(dict(zip(cols, [depth, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [depth, val_score, "val"])), ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %%
sns.lineplot(data=history, x = "n_depth", y = "AUC", hue = "dataset")
plt.show()

# %% [markdown]
# Różnica w skali na ostatnich dwóch wykresach jest ogromna, jedyna różnica między nimi - typ miary oceny.

# %%
rndForest = RandomForestClassifier(max_depth = 6, n_estimators=100)
rndForest.fit(X_train, y_train)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(rndForest, X_train, y_train)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(rndForest, X_val, y_val)
# Out:
# --------------------------------------------------
# Train set scores
# F1 score: [0.99024129 0.58823529]
# F1 score micro: 0.980934422794888
# F1 score weighted: 0.9771021846490834
# Precision score: [0.9806712 1.       ]
# Recall score: [1.         0.41666667]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.98279731 0.14814815]
# F1 score micro: 0.966275659824047
# F1 score weighted: 0.9546493152302982
# Precision score: [0.96902655 0.5       ]
# Recall score: [0.9969651  0.08695652]

# %% [markdown]
# Co ciekawe, pomimo zmnijeszenia przetrenowania modelu (trochę) predykcyjność jest niższa.
#
# ***
# ***

# %%
#W
rndForest = RandomForestClassifier()
rndForest.fit(X_trainv, y_trainv)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(rndForest, X_trainv, y_trainv)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(rndForest, X_valv, y_valv)
# Out:
# --------------------------------------------------
# Train set scores
# F1 score: [1. 1.]
# F1 score micro: 1.0
# F1 score weighted: 1.0
# Precision score: [1. 1.]
# Recall score: [1. 1.]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.98311445 0.30769231]
# F1 score micro: 0.967032967032967
# F1 score weighted: 0.9583737088427521
# Precision score: [0.97037037 0.66666667]
# Recall score: [0.99619772 0.2       ]

# %%
#W
cols = ["n_estimators","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(3,300,5)
for trees_nr in tqdm(estimators):
    rf = RandomForestClassifier(n_estimators=trees_nr, max_depth=5, n_jobs=-1).fit(X_trainv, y_trainv)
    train_score = roc_auc_score(y_trainv, rf.predict(X_trainv))
    val_score = roc_auc_score(y_valv, rf.predict(X_valv))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_estimators", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=60.0), HTML(value='')))

# %%
#W
sns.lineplot(data=history, x = "n_estimators", y = "AUC", hue = "dataset")
plt.show()

# %%
#W
cols = ["n_estimators","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(3,96,3)
for trees_nr in tqdm(estimators):
    rf = RandomForestClassifier(n_estimators=trees_nr, max_depth=5, n_jobs=-1).fit(X_trainv, y_trainv)
    train_score = roc_auc_score(y_trainv, rf.predict(X_trainv))
    val_score = roc_auc_score(y_valv, rf.predict(X_valv))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=31.0), HTML(value='')))

# %%
#W
sns.lineplot(data=history, x = "n_estimators", y = "AUC", hue = "dataset")
plt.show()

# %%
#W
cols = ["n_depth","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

n_depth = np.arange(1,10,1)
for depth in tqdm(n_depth):
    rf = RandomForestClassifier(max_depth=depth, n_jobs=-1, n_estimators=100).fit(X_trainv, y_trainv)
    train_score = roc_auc_score(y_trainv,rf.predict(X_trainv))
    val_score = roc_auc_score(y_valv,rf.predict(X_valv))
    history = history.append(dict(zip(cols, [depth, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [depth, val_score, "val"])), ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %%
#W
sns.lineplot(data=history, x = "n_depth", y = "AUC", hue = "dataset")
plt.show()

# %%
#W
cols = ["n_depth","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

n_depth = np.arange(1,10,1)
for depth in tqdm(n_depth):
    rf = RandomForestClassifier(max_depth=depth, n_jobs=-1, n_estimators=100).fit(X_trainv, y_trainv)
    train_score = rf.score(X_trainv,y_trainv)
    val_score = rf.score(X_valv,y_valv)
    history = history.append(dict(zip(cols, [depth, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [depth, val_score, "val"])), ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %%
#W
sns.lineplot(data=history, x = "n_depth", y = "AUC", hue = "dataset")
plt.show()

# %%
#W
rndForest = RandomForestClassifier(max_depth = 6, n_estimators=100)
rndForest.fit(X_trainv, y_trainv)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(rndForest, X_trainv, y_trainv)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(rndForest, X_valv, y_valv)
# Out:
# --------------------------------------------------
# Train set scores
# F1 score: [0.99577266 0.83018868]
# F1 score micro: 0.9917506874427131
# F1 score weighted: 0.9910677104235601
# Precision score: [0.99158092 1.        ]
# Recall score: [1.         0.70967742]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.98317757 0.18181818]
# F1 score micro: 0.967032967032967
# F1 score weighted: 0.9538237463471109
# Precision score: [0.96691176 1.        ]
# Recall score: [1.  0.1]

# %% [markdown]
# ## Klasyfikator `DecisionTreeClassifier`

# %%
d_tree = DecisionTreeClassifier(random_state=1)
d_tree.fit(X_train,y_train)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(d_tree, X_train, y_train)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(d_tree, X_val, y_val)
# Out:
# --------------------------------------------------
# Train set scores
# F1 score: [1. 1.]
# F1 score micro: 1.0
# F1 score weighted: 1.0
# Precision score: [1. 1.]
# Recall score: [1. 1.]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.97501893 0.23255814]
# F1 score micro: 0.9516129032258065
# F1 score weighted: 0.9499799249585296
# Precision score: [0.97280967 0.25      ]
# Recall score: [0.97723824 0.2173913 ]

# %% [markdown]
# W przypadku drzewa decyzyjnego, po raz pierwszy wynik precision i recall dla bankrtów jest porównywalny.

# %% [markdown]
# ---

# %%
cols = ["n_features","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(3,96,3)
for trees_nr in tqdm(estimators):
    rf = DecisionTreeClassifier(max_features=trees_nr, max_depth=5, random_state=1).fit(X_train, y_train)
    train_score = roc_auc_score(y_train, rf.predict(X_train))
    val_score = roc_auc_score(y_val, rf.predict(X_val))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_features", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=31.0), HTML(value='')))

# %% [markdown]
# ---

# %%
cols = ["n_features","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(1,30,1)
for trees_nr in tqdm(estimators):
    rf = DecisionTreeClassifier(max_features=trees_nr, max_depth=5, random_state=1).fit(X_train, y_train)
    train_score = roc_auc_score(y_train, rf.predict(X_train))
    val_score = roc_auc_score(y_val, rf.predict(X_val))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_features", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=29.0), HTML(value='')))

# %% [markdown]
# ---

# %%
cols = ["n_depth","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

n_depth = np.arange(1,10,1)
for depth in tqdm(n_depth):
    rf = DecisionTreeClassifier(max_depth=depth, random_state=1).fit(X_train, y_train)
    train_score = roc_auc_score(y_train,rf.predict(X_train))
    val_score = roc_auc_score(y_val,rf.predict(X_val))
    history = history.append(dict(zip(cols, [depth, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [depth, val_score, "val"])), ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %%
sns.lineplot(data=history, x = "n_depth", y = "AUC", hue = "dataset")
plt.show()

# %% [markdown]
# Tutaj widzimy wyraźny overfitting klasyfikatora `DecisionTreeClassifier`.

# %%
d_tree = DecisionTreeClassifier(max_depth=6, max_features=30, random_state=1)
d_tree.fit(X_train,y_train)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(d_tree, X_train, y_train)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(d_tree, X_val, y_val)
# Out:
# --------------------------------------------------
# Train set scores
# F1 score: [0.99053356 0.648     ]
# F1 score micro: 0.9815629583071444
# F1 score weighted: 0.9793382483872817
# Precision score: [0.98397093 0.86170213]
# Recall score: [0.99718432 0.51923077]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.97965335 0.27027027]
# F1 score micro: 0.9604105571847508
# F1 score weighted: 0.9557298770172824
# Precision score: [0.97305389 0.35714286]
# Recall score: [0.98634294 0.2173913 ]

# %%
d_tree = DecisionTreeClassifier(max_depth=8, max_features=30, random_state=1)
d_tree.fit(X_train,y_train)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(d_tree, X_train, y_train)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(d_tree, X_val, y_val)
# Out:
# --------------------------------------------------
# Train set scores
# F1 score: [0.99536188 0.84363636]
# F1 score micro: 0.990990990990991
# F1 score weighted: 0.9904029075898345
# Precision score: [0.99140524 0.97478992]
# Recall score: [0.99935023 0.74358974]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.98338369 0.45      ]
# F1 score micro: 0.967741935483871
# F1 score weighted: 0.9653956729363611
# Precision score: [0.97894737 0.52941176]
# Recall score: [0.98786039 0.39130435]

# %% [markdown]
# Przy pewnych parametrach udało się uzyskać lepszą predykcyjność niż dla domyślnych parametrów. Nadal Recall jest najważniejszą metryką co do poprawy predykcyjności, lecz różnica względem precision dla drzew decyzyjnych jest mniejsza.
#
# ***
# ***

# %%
#W
d_tree = DecisionTreeClassifier(random_state=1)
d_tree.fit(X_trainv,y_trainv)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(d_tree, X_trainv, y_trainv)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(d_tree, X_valv, y_valv)
# Out:
# --------------------------------------------------
# Train set scores
# F1 score: [1. 1.]
# F1 score micro: 1.0
# F1 score weighted: 1.0
# Precision score: [1. 1.]
# Recall score: [1. 1.]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.97109827 0.44444444]
# F1 score micro: 0.945054945054945
# F1 score weighted: 0.9518069171248361
# Precision score: [0.984375   0.35294118]
# Recall score: [0.9581749 0.6      ]

# %%
#W
cols = ["n_features","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(3,96,3)
for trees_nr in tqdm(estimators):
    rf = DecisionTreeClassifier(max_features=trees_nr, max_depth=5, random_state=1).fit(X_trainv, y_trainv)
    train_score = roc_auc_score(y_trainv, rf.predict(X_trainv))
    val_score = roc_auc_score(y_valv, rf.predict(X_valv))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_features", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=31.0), HTML(value='')))

# %%
#W
cols = ["n_features","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

estimators = np.arange(1,30,1)
for trees_nr in tqdm(estimators):
    rf = DecisionTreeClassifier(max_features=trees_nr, max_depth=5, random_state=1).fit(X_trainv, y_trainv)
    train_score = roc_auc_score(y_trainv, rf.predict(X_trainv))
    val_score = roc_auc_score(y_valv, rf.predict(X_valv))
    history = history.append(dict(zip(cols, [trees_nr, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [trees_nr, val_score, "val"])), ignore_index=True)

sns.lineplot(data=history, x = "n_features", y = "AUC", hue = "dataset")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=29.0), HTML(value='')))

# %%
#W
cols = ["n_depth","AUC", "dataset"]
history = pd.DataFrame(columns=cols)

n_depth = np.arange(1,10,1)
for depth in tqdm(n_depth):
    rf = DecisionTreeClassifier(max_depth=depth, random_state=1).fit(X_trainv, y_trainv)
    train_score = roc_auc_score(y_trainv,rf.predict(X_trainv))
    val_score = roc_auc_score(y_valv,rf.predict(X_valv))
    history = history.append(dict(zip(cols, [depth, train_score, "train"])), ignore_index=True)
    history = history.append(dict(zip(cols, [depth, val_score, "val"])), ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %%
#W
sns.lineplot(data=history, x = "n_depth", y = "AUC", hue = "dataset")
plt.show()

# %%
#W
d_tree = DecisionTreeClassifier(max_depth=6, max_features=30, random_state=1)
d_tree.fit(X_trainv,y_trainv)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(d_tree, X_trainv, y_trainv)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(d_tree, X_valv, y_valv)
# Out:
# --------------------------------------------------
# Train set scores
# F1 score: [0.99343955 0.70833333]
# F1 score micro: 0.9871677360219981
# F1 score weighted: 0.985338456904078
# Precision score: [0.98696462 1.        ]
# Recall score: [1.        0.5483871]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.97744361 0.14285714]
# F1 score micro: 0.9560439560439561
# F1 score weighted: 0.9468726761959845
# Precision score: [0.96654275 0.25      ]
# Recall score: [0.98859316 0.1       ]

# %%
#W
d_tree = DecisionTreeClassifier(max_depth=8, max_features=30, random_state=1)
d_tree.fit(X_trainv,y_trainv)

print("--------------------------------------------------")
print("Train set scores")
show_model_metrics(d_tree, X_trainv, y_trainv)

print("--------------------------------------------------")
print("Validation set scores")
show_model_metrics(d_tree, X_valv, y_valv)
# Out:
# --------------------------------------------------
# Train set scores
# F1 score: [0.99811676 0.93103448]
# F1 score micro: 0.9963336388634281
# F1 score weighted: 0.9962106649347936
# Precision score: [0.9962406 1.       ]
# Recall score: [1.         0.87096774]
# --------------------------------------------------
# Validation set scores
# F1 score: [0.97338403 0.3       ]
# F1 score micro: 0.9487179487179487
# F1 score weighted: 0.9487179487179487
# Precision score: [0.97338403 0.3       ]
# Recall score: [0.97338403 0.3       ]

# %% [markdown]
# ## Wnioski

# %% [markdown]
# W powyższym porównaniu klasyfikatorów, gdy parametry modelu przyjmowały wartości domyślne, najlepszy był się `XGBClassifier`.
# W sytuacjach, w których w ręczny sposób dobrane zostały parametry, najskuteczniejszy okazał się `DecisionTreeClassifier`.
